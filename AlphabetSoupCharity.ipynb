# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf
from google.colab import drive
drive.mount('/content/drive/')
# %cd /content/drive/My Drive/Colab Notebooks/Charity Funding Predictor/Resources/
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/My Drive/Colab Notebooks/Charity Funding Predictor/Resources

# %%
#  Import and read the charity data.csv
import pandas as pd 
df = pd.read_csv("charity_data.csv")
df.head()
# Out:
#         EIN                                      NAME  ... ASK_AMT IS_SUCCESSFUL
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB  ...    5000             1
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR  ...  108590             1
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS  ...    5000             0
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION  ...    6692             1
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT  ...  142590             1
#
# [5 rows x 12 columns]

# %%
#Drop 'EIN' and 'Name' columns 
df = df.drop(columns=['EIN', 'NAME'])
df
# Out:
#       APPLICATION_TYPE       AFFILIATION  ...   ASK_AMT IS_SUCCESSFUL
# 0                  T10       Independent  ...      5000             1
# 1                   T3       Independent  ...    108590             1
# 2                   T5  CompanySponsored  ...      5000             0
# 3                   T3  CompanySponsored  ...      6692             1
# 4                   T3       Independent  ...    142590             1
# ...                ...               ...  ...       ...           ...
# 34294               T4       Independent  ...      5000             0
# 34295               T4  CompanySponsored  ...      5000             0
# 34296               T3  CompanySponsored  ...      5000             0
# 34297               T5       Independent  ...      5000             1
# 34298               T3       Independent  ...  36500179             0
#
# [34299 rows x 10 columns]

# %%
#Determine the number of unique values for each column
df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
binning_count = df['APPLICATION_TYPE'].value_counts()
binning_count
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T15        2
# T29        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(binning_count[binning_count<500].index)
application_types_to_replace


# Replace in dataframe
for app in application_types_to_replace:
    df['APPLICATION_TYPE'] = df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_binning = df['CLASSIFICATION'].value_counts()
classification_binning
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C1248        1
# C5200        1
# C4200        1
# C8210        1
# C1570        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_binning = classification_binning[classification_binning>1]
classification_binning
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C6000       15
# C1800       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1237        9
# C1235        9
# C7210        7
# C4100        6
# C2400        6
# C1720        6
# C1257        5
# C1600        5
# C2710        3
# C1260        3
# C0           3
# C1256        2
# C1234        2
# C1267        2
# C1246        2
# C3200        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`

classifications_to_replace = classification_binning[classification_binning <= 100]
classifications_to_replace

# Look at CLASSIFICATION value counts for binning
df['CLASSIFICATION'] = df['CLASSIFICATION'].replace(classifications_to_replace.index, 'Other')

# Check to make sure binning was successful
df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      643
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2170        1
# C1370        1
# C4500        1
# C3700        1
# C1820        1
# C1245        1
# C4120        1
# C2600        1
# C2561        1
# C1732        1
# C1570        1
# C4200        1
# C5200        1
# C8210        1
# C1728        1
# C1283        1
# C2380        1
# C2190        1
# C2500        1
# C6100        1
# C1236        1
# C1580        1
# C2570        1
# C1900        1
# C2150        1
# C1248        1
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
df = pd.get_dummies(df,dtype=float)
df.head()
# Out:
#    STATUS  ASK_AMT  ...  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0       1     5000  ...                       1.0                       0.0
# 1       1   108590  ...                       1.0                       0.0
# 2       1     5000  ...                       1.0                       0.0
# 3       1     6692  ...                       1.0                       0.0
# 4       1   142590  ...                       1.0                       0.0
#
# [5 rows x 76 columns]

# %%
# Split our preprocessed data into our features and target arrays
Y = df["IS_SUCCESSFUL"]
X = df.drop(columns=["IS_SUCCESSFUL"])


# Split the preprocessed data into a training and testing dataset
x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state = 42)

# %%
# Create a StandardScaler instances  (make it into normal distribution)
scaler = StandardScaler()

# Fit the StandardScaler
x_scaler = scaler.fit(x_train)

# Scale the data
x_train_scaled = x_scaler.transform(x_train)
x_test_scaled = x_scaler.transform(x_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.


nn = tf.keras.models.Sequential()

features = 75
neurons = 20


# set up the first input / features layer
nn.add(tf.keras.Input(shape=(features)))


# First hidden layer
nn.add(tf.keras.layers.Dense(neurons, activation="relu"))


# Second hidden layer
nn.add(tf.keras.layers.Dense(neurons, activation="relu"))


# Output layer

nn.add(tf.keras.layers.Dense(1, activation="sigmoid"))


# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_36 (Dense)            (None, 20)                1520
#
#  dense_37 (Dense)            (None, 20)                420
#
#  dense_38 (Dense)            (None, 1)                 21
#
# =================================================================
# Total params: 1,961
# Trainable params: 1,961
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])

# %%
# Train the model 
fit_model = nn.fit(x_train_scaled, y_train, epochs =100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5921 - accuracy: 0.7076
# Epoch 2/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5580 - accuracy: 0.7269
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5527 - accuracy: 0.7285
# Epoch 4/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5501 - accuracy: 0.7297
# Epoch 5/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5486 - accuracy: 0.7290
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5478 - accuracy: 0.7304
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5469 - accuracy: 0.7313
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5466 - accuracy: 0.7319
# Epoch 9/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5465 - accuracy: 0.7317
# Epoch 10/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5452 - accuracy: 0.7318
# Epoch 11/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5448 - accuracy: 0.7332
# Epoch 12/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5441 - accuracy: 0.7328
# Epoch 13/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5439 - accuracy: 0.7325
# Epoch 14/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5433 - accuracy: 0.7332
# Epoch 15/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5435 - accuracy: 0.7320
# Epoch 16/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5423 - accuracy: 0.7334
# Epoch 17/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5423 - accuracy: 0.7325
# Epoch 18/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5426 - accuracy: 0.7322
# Epoch 19/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5417 - accuracy: 0.7329
# Epoch 20/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5413 - accuracy: 0.7336
# Epoch 21/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5417 - accuracy: 0.7331
# Epoch 22/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5413 - accuracy: 0.7345
# Epoch 23/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5408 - accuracy: 0.7346
# Epoch 24/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5413 - accuracy: 0.7353
# Epoch 25/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5402 - accuracy: 0.7344
# Epoch 26/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5413 - accuracy: 0.7343
# Epoch 27/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5402 - accuracy: 0.7351
# Epoch 28/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5405 - accuracy: 0.7359
# Epoch 29/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5397 - accuracy: 0.7368
# Epoch 30/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5403 - accuracy: 0.7361
# Epoch 31/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5395 - accuracy: 0.7361
# Epoch 32/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5400 - accuracy: 0.7357
# Epoch 33/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5397 - accuracy: 0.7345
# Epoch 34/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5392 - accuracy: 0.7368
# Epoch 35/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5396 - accuracy: 0.7352
# Epoch 36/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5391 - accuracy: 0.7360
# Epoch 37/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5392 - accuracy: 0.7351
# Epoch 38/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5388 - accuracy: 0.7368
# Epoch 39/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5385 - accuracy: 0.7350
# Epoch 40/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5389 - accuracy: 0.7361
# Epoch 41/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5389 - accuracy: 0.7369
# Epoch 42/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5382 - accuracy: 0.7380
# Epoch 43/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5387 - accuracy: 0.7360
# Epoch 44/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5385 - accuracy: 0.7370
# Epoch 45/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5385 - accuracy: 0.7370
# Epoch 46/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5383 - accuracy: 0.7365
# Epoch 47/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5384 - accuracy: 0.7364
# Epoch 48/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5381 - accuracy: 0.7364
# Epoch 49/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5377 - accuracy: 0.7371
# Epoch 50/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5377 - accuracy: 0.7358
# Epoch 51/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5376 - accuracy: 0.7369
# Epoch 52/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5374 - accuracy: 0.7368
# Epoch 53/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5374 - accuracy: 0.7372
# Epoch 54/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5375 - accuracy: 0.7374
# Epoch 55/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5371 - accuracy: 0.7373
# Epoch 56/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5372 - accuracy: 0.7377
# Epoch 57/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5370 - accuracy: 0.7375
# Epoch 58/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5369 - accuracy: 0.7370
# Epoch 59/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5367 - accuracy: 0.7373
# Epoch 60/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5365 - accuracy: 0.7378
# Epoch 61/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5367 - accuracy: 0.7379
# Epoch 62/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5368 - accuracy: 0.7378
# Epoch 63/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5368 - accuracy: 0.7374
# Epoch 64/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5366 - accuracy: 0.7376
# Epoch 65/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5371 - accuracy: 0.7378
# Epoch 66/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5368 - accuracy: 0.7374
# Epoch 67/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5361 - accuracy: 0.7367
# Epoch 68/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5362 - accuracy: 0.7375
# Epoch 69/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5354 - accuracy: 0.7387
# Epoch 70/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5359 - accuracy: 0.7372
# Epoch 71/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5359 - accuracy: 0.7380
# Epoch 72/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5365 - accuracy: 0.7372
# Epoch 73/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5355 - accuracy: 0.7381
# Epoch 74/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5358 - accuracy: 0.7383
# Epoch 75/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5356 - accuracy: 0.7381
# Epoch 76/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5356 - accuracy: 0.7377
# Epoch 77/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5361 - accuracy: 0.7375
# Epoch 78/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5354 - accuracy: 0.7384
# Epoch 79/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5356 - accuracy: 0.7380
# Epoch 80/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5354 - accuracy: 0.7381
# Epoch 81/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5353 - accuracy: 0.7376
# Epoch 82/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5353 - accuracy: 0.7390
# Epoch 83/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5351 - accuracy: 0.7381
# Epoch 84/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5345 - accuracy: 0.7377
# Epoch 85/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5350 - accuracy: 0.7377
# Epoch 86/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5351 - accuracy: 0.7385
# Epoch 87/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5351 - accuracy: 0.7390
# Epoch 88/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5351 - accuracy: 0.7386
# Epoch 89/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5349 - accuracy: 0.7379
# Epoch 90/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5347 - accuracy: 0.7388
# Epoch 91/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5347 - accuracy: 0.7380
# Epoch 92/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5347 - accuracy: 0.7386
# Epoch 93/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5347 - accuracy: 0.7375
# Epoch 94/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7390
# Epoch 95/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5346 - accuracy: 0.7376
# Epoch 96/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5345 - accuracy: 0.7387
# Epoch 97/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5348 - accuracy: 0.7383
# Epoch 98/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5341 - accuracy: 0.7398
# Epoch 99/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5345 - accuracy: 0.7381
# Epoch 100/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5344 - accuracy: 0.7388

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(x_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5533 - accuracy: 0.7321 - 416ms/epoch - 2ms/step
# Loss: 0.5532832145690918, Accuracy: 0.7321282625198364

# %%
# Export our model to HDF5 file
from google.colab import files

nn.save('/content/AlphabetSoupCharity.h5')
