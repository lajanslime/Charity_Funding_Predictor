# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf
from google.colab import drive
drive.mount('/content/drive/')
# %cd /content/drive/My Drive/Colab Notebooks/Charity Funding Predictor/Resources/
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/My Drive/Colab Notebooks/Charity Funding Predictor/Resources

# %%
#  Import and read the charity data.csv
import pandas as pd 
df = pd.read_csv("charity_data.csv")
df.head()
# Out:
#         EIN                                      NAME  ... ASK_AMT IS_SUCCESSFUL
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB  ...    5000             1
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR  ...  108590             1
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS  ...    5000             0
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION  ...    6692             1
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT  ...  142590             1
#
# [5 rows x 12 columns]

# %%
#Drop 'EIN' and 'Name' and 'SPECIAL_CONSIDERATIONS' columns 
df = df.drop(columns=['EIN', 'NAME','SPECIAL_CONSIDERATIONS', 'ORGANIZATION'])
df
# Out:
#       APPLICATION_TYPE       AFFILIATION  ...   ASK_AMT IS_SUCCESSFUL
# 0                  T10       Independent  ...      5000             1
# 1                   T3       Independent  ...    108590             1
# 2                   T5  CompanySponsored  ...      5000             0
# 3                   T3  CompanySponsored  ...      6692             1
# 4                   T3       Independent  ...    142590             1
# ...                ...               ...  ...       ...           ...
# 34294               T4       Independent  ...      5000             0
# 34295               T4  CompanySponsored  ...      5000             0
# 34296               T3  CompanySponsored  ...      5000             0
# 34297               T5       Independent  ...      5000             1
# 34298               T3       Independent  ...  36500179             0
#
# [34299 rows x 8 columns]

# %%
#Determine the number of unique values for each column
df.nunique()
# Out:
# APPLICATION_TYPE      17
# AFFILIATION            6
# CLASSIFICATION        71
# USE_CASE               5
# STATUS                 2
# INCOME_AMT             9
# ASK_AMT             8747
# IS_SUCCESSFUL          2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
binning_count = df['APPLICATION_TYPE'].value_counts()
binning_count
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T14        3
# T25        3
# T15        2
# T29        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(binning_count[binning_count<500].index)
application_types_to_replace

# Replace in dataframe
for app in application_types_to_replace:
    df['APPLICATION_TYPE'] = df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_binning = df['CLASSIFICATION'].value_counts()
classification_binning
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C1820        1
# C1283        1
# C4500        1
# C1245        1
# C6100        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`

classifications_to_replace = list(classification_binning[classification_binning < 100].index)
classifications_to_replace

# Replace in dataframe
for cls in classifications_to_replace:
    df['CLASSIFICATION'] = df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      669
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
df = pd.get_dummies(df,dtype=float)
df.head()
# Out:
#    STATUS  ASK_AMT  ...  INCOME_AMT_50M+  INCOME_AMT_5M-10M
# 0       1     5000  ...              0.0                0.0
# 1       1   108590  ...              0.0                0.0
# 2       1     5000  ...              0.0                0.0
# 3       1     6692  ...              0.0                0.0
# 4       1   142590  ...              0.0                0.0
#
# [5 rows x 44 columns]

# %%
# Split our preprocessed data into our features and target arrays
Y = df["IS_SUCCESSFUL"]
X = df.drop(columns=["IS_SUCCESSFUL"])


# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, Y, random_state = 78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
features = len(X_train_scaled[0])

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units= 100, input_dim=features, activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units= 50, activation='sigmoid'))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units= 30, activation='sigmoid'))

# Fourth hidden layer
nn.add(tf.keras.layers.Dense(units= 50, activation='sigmoid'))

nn.add(tf.keras.layers.Dense(units= 60, activation='relu'))

nn.add(tf.keras.layers.Dense(units= 40, activation='sigmoid'))

nn.add(tf.keras.layers.Dense(units= 40, activation='sigmoid'))

nn.add(tf.keras.layers.Dense(units= 40, activation='relu'))

nn.add(tf.keras.layers.Dense(units= 40, activation='sigmoid'))


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 100)               4400
#
#  dense_6 (Dense)             (None, 50)                5050
#
#  dense_7 (Dense)             (None, 30)                1530
#
#  dense_8 (Dense)             (None, 50)                1550
#
#  dense_9 (Dense)             (None, 60)                3060
#
#  dense_10 (Dense)            (None, 40)                2440
#
#  dense_11 (Dense)            (None, 40)                1640
#
#  dense_12 (Dense)            (None, 40)                1640
#
#  dense_13 (Dense)            (None, 40)                1640
#
#  dense_14 (Dense)            (None, 1)                 41
#
# =================================================================
# Total params: 22,991
# Trainable params: 22,991
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])

# %%
# Train the model 
fit_model = nn.fit(X_train_scaled, y_train, epochs=150)
# Out:
# Epoch 1/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.6123 - accuracy: 0.6833
# Epoch 2/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5773 - accuracy: 0.7281
# Epoch 3/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5703 - accuracy: 0.7283
# Epoch 4/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5647 - accuracy: 0.7293
# Epoch 5/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5627 - accuracy: 0.7285
# Epoch 6/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5610 - accuracy: 0.7294
# Epoch 7/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5597 - accuracy: 0.7303
# Epoch 8/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5585 - accuracy: 0.7309
# Epoch 9/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5584 - accuracy: 0.7313
# Epoch 10/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5577 - accuracy: 0.7308
# Epoch 11/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5566 - accuracy: 0.7310
# Epoch 12/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5564 - accuracy: 0.7310
# Epoch 13/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5557 - accuracy: 0.7319
# Epoch 14/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5552 - accuracy: 0.7316
# Epoch 15/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5557 - accuracy: 0.7310
# Epoch 16/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5545 - accuracy: 0.7326
# Epoch 17/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5541 - accuracy: 0.7318
# Epoch 18/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5542 - accuracy: 0.7318
# Epoch 19/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5530 - accuracy: 0.7328
# Epoch 20/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5540 - accuracy: 0.7320
# Epoch 21/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5534 - accuracy: 0.7324
# Epoch 22/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5529 - accuracy: 0.7321
# Epoch 23/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5531 - accuracy: 0.7317
# Epoch 24/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5529 - accuracy: 0.7325
# Epoch 25/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5522 - accuracy: 0.7331
# Epoch 26/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5529 - accuracy: 0.7332
# Epoch 27/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5524 - accuracy: 0.7329
# Epoch 28/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5515 - accuracy: 0.7332
# Epoch 29/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5518 - accuracy: 0.7328
# Epoch 30/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5512 - accuracy: 0.7336
# Epoch 31/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5514 - accuracy: 0.7339
# Epoch 32/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5511 - accuracy: 0.7324
# Epoch 33/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5509 - accuracy: 0.7334
# Epoch 34/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5507 - accuracy: 0.7332
# Epoch 35/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5506 - accuracy: 0.7328
# Epoch 36/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5507 - accuracy: 0.7336
# Epoch 37/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5497 - accuracy: 0.7338
# Epoch 38/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5500 - accuracy: 0.7325
# Epoch 39/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5499 - accuracy: 0.7340
# Epoch 40/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5497 - accuracy: 0.7339
# Epoch 41/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5498 - accuracy: 0.7337
# Epoch 42/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5493 - accuracy: 0.7336
# Epoch 43/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5493 - accuracy: 0.7339
# Epoch 44/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5494 - accuracy: 0.7342
# Epoch 45/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5493 - accuracy: 0.7340
# Epoch 46/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5489 - accuracy: 0.7340
# Epoch 47/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5492 - accuracy: 0.7340
# Epoch 48/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5494 - accuracy: 0.7340
# Epoch 49/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5486 - accuracy: 0.7341
# Epoch 50/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5488 - accuracy: 0.7341
# Epoch 51/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5486 - accuracy: 0.7342
# Epoch 52/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5484 - accuracy: 0.7342
# Epoch 53/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5485 - accuracy: 0.7342
# Epoch 54/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5490 - accuracy: 0.7342
# Epoch 55/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5486 - accuracy: 0.7332
# Epoch 56/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5482 - accuracy: 0.7346
# Epoch 57/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5479 - accuracy: 0.7342
# Epoch 58/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5481 - accuracy: 0.7342
# Epoch 59/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5478 - accuracy: 0.7344
# Epoch 60/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5480 - accuracy: 0.7346
# Epoch 61/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5481 - accuracy: 0.7348
# Epoch 62/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5478 - accuracy: 0.7350
# Epoch 63/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5477 - accuracy: 0.7339
# Epoch 64/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5484 - accuracy: 0.7340
# Epoch 65/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5475 - accuracy: 0.7342
# Epoch 66/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5479 - accuracy: 0.7348
# Epoch 67/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5490 - accuracy: 0.7350
# Epoch 68/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5474 - accuracy: 0.7344
# Epoch 69/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5476 - accuracy: 0.7347
# Epoch 70/150
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5475 - accuracy: 0.7345
# Epoch 71/150
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5477 - accuracy: 0.7338
# Epoch 72/150
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5476 - accuracy: 0.7348
# Epoch 73/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5475 - accuracy: 0.7345
# Epoch 74/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5473 - accuracy: 0.7350
# Epoch 75/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5473 - accuracy: 0.7349
# Epoch 76/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5470 - accuracy: 0.7349
# Epoch 77/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5473 - accuracy: 0.7346
# Epoch 78/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5473 - accuracy: 0.7338
# Epoch 79/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5467 - accuracy: 0.7354
# Epoch 80/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5470 - accuracy: 0.7341
# Epoch 81/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5475 - accuracy: 0.7345
# Epoch 82/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5467 - accuracy: 0.7353
# Epoch 83/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5468 - accuracy: 0.7352
# Epoch 84/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5469 - accuracy: 0.7350
# Epoch 85/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5467 - accuracy: 0.7345
# Epoch 86/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5477 - accuracy: 0.7353
# Epoch 87/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5468 - accuracy: 0.7352
# Epoch 88/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5466 - accuracy: 0.7353
# Epoch 89/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5466 - accuracy: 0.7350
# Epoch 90/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5471 - accuracy: 0.7349
# Epoch 91/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5463 - accuracy: 0.7355
# Epoch 92/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5467 - accuracy: 0.7351
# Epoch 93/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5462 - accuracy: 0.7351
# Epoch 94/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5467 - accuracy: 0.7358
# Epoch 95/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5462 - accuracy: 0.7349
# Epoch 96/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5460 - accuracy: 0.7353
# Epoch 97/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5462 - accuracy: 0.7355
# Epoch 98/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5471 - accuracy: 0.7345
# Epoch 99/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5464 - accuracy: 0.7349
# Epoch 100/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5467 - accuracy: 0.7354
# Epoch 101/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5463 - accuracy: 0.7350
# Epoch 102/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5463 - accuracy: 0.7352
# Epoch 103/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5458 - accuracy: 0.7351
# Epoch 104/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5470 - accuracy: 0.7355
# Epoch 105/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5467 - accuracy: 0.7350
# Epoch 106/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5465 - accuracy: 0.7353
# Epoch 107/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5472 - accuracy: 0.7346
# Epoch 108/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5470 - accuracy: 0.7351
# Epoch 109/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5464 - accuracy: 0.7348
# Epoch 110/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5464 - accuracy: 0.7352
# Epoch 111/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5460 - accuracy: 0.7354
# Epoch 112/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5462 - accuracy: 0.7353
# Epoch 113/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5465 - accuracy: 0.7351
# Epoch 114/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5466 - accuracy: 0.7356
# Epoch 115/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5468 - accuracy: 0.7353
# Epoch 116/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5476 - accuracy: 0.7355
# Epoch 117/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5462 - accuracy: 0.7359
# Epoch 118/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5469 - accuracy: 0.7354
# Epoch 119/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5473 - accuracy: 0.7355
# Epoch 120/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5465 - accuracy: 0.7357
# Epoch 121/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5461 - accuracy: 0.7355
# Epoch 122/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5468 - accuracy: 0.7355
# Epoch 123/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5463 - accuracy: 0.7357
# Epoch 124/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5464 - accuracy: 0.7352
# Epoch 125/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5468 - accuracy: 0.7352
# Epoch 126/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5460 - accuracy: 0.7353
# Epoch 127/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5459 - accuracy: 0.7357
# Epoch 128/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5460 - accuracy: 0.7353
# Epoch 129/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5466 - accuracy: 0.7355
# Epoch 130/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5476 - accuracy: 0.7344
# Epoch 131/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5474 - accuracy: 0.7347
# Epoch 132/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5467 - accuracy: 0.7357
# Epoch 133/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5469 - accuracy: 0.7354
# Epoch 134/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5475 - accuracy: 0.7352
# Epoch 135/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5476 - accuracy: 0.7346
# Epoch 136/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5473 - accuracy: 0.7358
# Epoch 137/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5472 - accuracy: 0.7350
# Epoch 138/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5469 - accuracy: 0.7353
# Epoch 139/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5462 - accuracy: 0.7356
# Epoch 140/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5470 - accuracy: 0.7352
# Epoch 141/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5502 - accuracy: 0.7353
# Epoch 142/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5475 - accuracy: 0.7358
# Epoch 143/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5467 - accuracy: 0.7360
# Epoch 144/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5467 - accuracy: 0.7353
# Epoch 145/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5467 - accuracy: 0.7352
# Epoch 146/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5467 - accuracy: 0.7351
# Epoch 147/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5466 - accuracy: 0.7352
# Epoch 148/150
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5466 - accuracy: 0.7354
# Epoch 149/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5466 - accuracy: 0.7346
# Epoch 150/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5472 - accuracy: 0.7355

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5625 - accuracy: 0.7236 - 475ms/epoch - 2ms/step
# Loss: 0.5624586343765259, Accuracy: 0.7236151695251465

# %%
# Export our model to HDF5 file
from google.colab import files

nn.save('/content/AlphabetSoupCharity_Optimzation4.h5')
nn.save('AlphabetSoupCharity_Optimzation4.h5')
